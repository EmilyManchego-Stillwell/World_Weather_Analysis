# %%
#Import dependencies
import random

# %% [markdown]
# # Generating random numbers using randint() function.

# %%
random.randint(-90,90)
# Out:
# 88

# %% [markdown]
# # Generating random numbers using the random() function

# %%
random.random()
# Out:
# 0.08564494910835074

# %% [markdown]
# # Combining randint() and random() functions

# %%
random_number = random.randint(-90,89) + random.random()
random_number
# Out:
# -44.636101878342075

# %%
x=1
latitudes =[]

while x < 11:
    random_lat = random.randint(-90,89) + random.random()
    latitudes.append(random_lat)
    x += 1
    
print(latitudes)
# Out:
# [-14.430183010676592, 61.315099142424934, -40.600108525244075, 70.07834402614277, -64.39622079626136, -45.67027909000335, 48.2471392497738, 39.63651649430962, -78.73932550646481, 31.24775057539163]

# %%
random.randrange(-90,90, step=1)
# Out:
# -87

# %%
random.randrange(-90,90, step=3)
# Out:
# 24

# %%
random.uniform(-90,90)
# Out:
# 43.04469064352281

# %%
#Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# -51.078484481505

# %%
np.random.uniform(-90,90)
# Out:
# 38.261266886119785

# %%
np.random.uniform(-90,90,size=50)
# Out:
# array([ 60.99845752,  27.46409812, -13.3884108 , -84.25429983,
#          5.93071398,  26.65506119, -74.8407119 , -44.5507463 ,
#         31.16085408,  23.55086421, -33.51986292, -20.88068095,
#         38.05033631, -11.39014619,  22.58450694,  35.4478984 ,
#          5.89699841, -60.18467128,  23.66377801, -30.30534693,
#         53.50136371,   6.74533474,  16.1153817 ,  46.53085451,
#         46.61320077,  51.92221791,  53.06304591, -81.68682079,
#         53.93626467,  72.1297234 ,  14.97387858,  69.92848981,
#         21.55545763, -64.76976855, -80.38624141,  11.3259447 ,
#        -41.94746253,  65.35204401, -14.23398939, -78.55858316,
#        -76.21213131,  19.62747201, -55.7824571 ,  22.89968897,
#         89.45659278, -70.42906562, -16.09199803,  62.2511819 ,
#        -41.70572795, -38.12574212])

# %%
#Import timeit
import timeit

# %%
# %timeit np.random.uniform(-90.000,90.000,size=1500)
# Out:
# 12.4 µs ± 23.3 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x=0
    while x < (size):
        random_lat = random.randint(-90,90) + random.random()
        latitudes.append(random_lat)
        x+=1
    return latitudes

#Call the function with 1500
print(latitudes(1500))
# Out:
# [-10.367279630302008, 9.072582535155187, -26.006851030083986, -86.72376959908023, -70.08036259102877, 49.43418688110721, 84.65612118873152, 67.71336606901968, 66.80239820492365, 49.97117060635729, -54.45749475731276, 65.53111690891531, -78.91438866492241, 3.882150390781737, -29.81700335781477, -74.61485103300653, 32.964944269988834, -29.513312183145043, 67.91432112529165, 19.241632868786827, -8.06348208519711, 88.72775171907281, -4.276924581942312, 88.58774786120277, -64.4542323813203, -38.13501008503028, 19.95715584414481, 77.62316479894028, -23.90154151734084, 31.457982592129405, 57.393440240795904, -59.49634747260314, 67.63633471823997, 50.36096833456048, -13.586950894562609, 30.108293514402867, -80.88559122537211, 60.62439901666998, -82.54431347106087, -88.8808949028607, -67.50333192829258, -46.69499851093316, 38.325982525701995, -17.869157384226924, -73.51867081478086, -36.564397309740464, 6.630829870230356, 73.667872027363, 82.96113517571055, 41.25447391061633, -17.21432278737338, 60.82664312052481, -62.04738496268019, 23.53813033241867, 22.477266402615264, -49.67672319265013, 65.52787250107764, -56.49854552